# %%
import pandas as pd

# %%
df = pd.read_csv('weatherAUS.csv')

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
pd.set_option('display.max_columns',23)

# %%
# Finding average maximum temperature
df['MaxTemp'].mean()
# Out:
# 23.221348275647003

# %%
# Finding average maximum temperature
df['MinTemp'].mean()
# Out:
# 12.19403438096871

# %%
Loc_grp = df.groupby(['Location'])

# %%
Loc_grp.get_group('Cobar')
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049  2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 6050  2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 6051  2009-01-03    Cobar     15.5     34.1       0.0         12.6      13.3
# 6052  2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 6053  2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# ...          ...      ...      ...      ...       ...          ...       ...
# 9053  2017-06-21    Cobar      5.8     19.1       0.0          NaN       NaN
# 9054  2017-06-22    Cobar      2.8     19.2       0.0          NaN       NaN
# 9055  2017-06-23    Cobar      6.9     20.0       0.0          NaN       NaN
# 9056  2017-06-24    Cobar      8.3     16.2       0.0          NaN       NaN
# 9057  2017-06-25    Cobar      9.1     22.0       0.0          NaN       NaN
#
# ...

# %%
# Finding average maximum temperature in location Cobar
Loc_grp.get_group('Cobar').MaxTemp.mean()
# Out:
# 25.870093147039235

# %%
# Count of null values in column Evaporation  # .count() method gives number of non null values
df['Evaporation'].isnull().sum()
# Out:
# 62790

# %%
# Count of null values in column Sunshine
df['Sunshine'].isnull().sum()
# Out:
# 69835

# %%
# Dropping the date column
df = df.drop(['Date'],axis=1)
df
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        Albury     13.4     22.9       0.6          NaN       NaN
# 1        Albury      7.4     25.1       0.0          NaN       NaN
# 2        Albury     12.9     25.7       0.0          NaN       NaN
# 3        Albury      9.2     28.0       0.0          NaN       NaN
# 4        Albury     17.5     32.3       1.0          NaN       NaN
# ...         ...      ...      ...       ...          ...       ...
# 145455    Uluru      2.8     23.4       0.0          NaN       NaN
# 145456    Uluru      3.6     25.3       0.0          NaN       NaN
# 145457    Uluru      5.4     26.9       0.0          NaN       NaN
# 145458    Uluru      7.8     27.0       0.0          NaN       NaN
# 145459    Uluru     14.9      NaN       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0                W           44.0          W        WNW          20.0
# ...

# %%
# For column evaporation, replace all missing values with average of the column
df['Evaporation'].fillna(df['Evaporation'].mean() , inplace=True)
df
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        Albury     13.4     22.9       0.6     5.468232       NaN
# 1        Albury      7.4     25.1       0.0     5.468232       NaN
# 2        Albury     12.9     25.7       0.0     5.468232       NaN
# 3        Albury      9.2     28.0       0.0     5.468232       NaN
# 4        Albury     17.5     32.3       1.0     5.468232       NaN
# ...         ...      ...      ...       ...          ...       ...
# 145455    Uluru      2.8     23.4       0.0     5.468232       NaN
# 145456    Uluru      3.6     25.3       0.0     5.468232       NaN
# 145457    Uluru      5.4     26.9       0.0     5.468232       NaN
# 145458    Uluru      7.8     27.0       0.0     5.468232       NaN
# 145459    Uluru     14.9      NaN       0.0     5.468232       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0                W           44.0          W        WNW          20.0
# ...

# %%
df.dropna(axis='columns' , how='any')
# Out:
#        Location  Evaporation
# 0        Albury     5.468232
# 1        Albury     5.468232
# 2        Albury     5.468232
# 3        Albury     5.468232
# 4        Albury     5.468232
# ...         ...          ...
# 145455    Uluru     5.468232
# 145456    Uluru     5.468232
# 145457    Uluru     5.468232
# 145458    Uluru     5.468232
# 145459    Uluru     5.468232
#
# [145460 rows x 2 columns]

# %%
df
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        Albury     13.4     22.9       0.6     5.468232       NaN
# 1        Albury      7.4     25.1       0.0     5.468232       NaN
# 2        Albury     12.9     25.7       0.0     5.468232       NaN
# 3        Albury      9.2     28.0       0.0     5.468232       NaN
# 4        Albury     17.5     32.3       1.0     5.468232       NaN
# ...         ...      ...      ...       ...          ...       ...
# 145455    Uluru      2.8     23.4       0.0     5.468232       NaN
# 145456    Uluru      3.6     25.3       0.0     5.468232       NaN
# 145457    Uluru      5.4     26.9       0.0     5.468232       NaN
# 145458    Uluru      7.8     27.0       0.0     5.468232       NaN
# 145459    Uluru     14.9      NaN       0.0     5.468232       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0                W           44.0          W        WNW          20.0
# ...

# %%
#Making a user defined function where all details of country entered by the user are displayed
def ShowData(country):
    filt = (df['Location'] == country)
    print(df.loc[filt])
country = input("Enter country whose details you want to filter")
ShowData(country)
# Out:
# Enter country whose details you want to filterAlbury
#      Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      Albury     13.4     22.9       0.6     5.468232       NaN           W
# 1      Albury      7.4     25.1       0.0     5.468232       NaN         WNW
# 2      Albury     12.9     25.7       0.0     5.468232       NaN         WSW
# 3      Albury      9.2     28.0       0.0     5.468232       NaN          NE
# 4      Albury     17.5     32.3       1.0     5.468232       NaN           W
# ...       ...      ...      ...       ...          ...       ...         ...
# 3035   Albury      1.2     15.2       0.4     5.468232       NaN         ENE
# 3036   Albury      0.8     13.4       0.0     5.468232       NaN           W
# 3037   Albury      1.1     11.9       0.0     5.468232       NaN          SE
# 3038   Albury      1.1     14.1       0.2     5.468232       NaN         WSW
# ...

# %%
def ShowData(country):
    filt = (df['Location'] == country)
    print(df.loc[filt])
country = input("Enter country whose details you want to filter")
ShowData(country)
# Out:
# Enter country whose details you want to filterUluru
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 143882    Uluru     19.7     30.0       0.8     5.468232       NaN
# 143883    Uluru     21.6     33.1       0.0     5.468232       NaN
# 143884    Uluru     21.3     36.1       0.0     5.468232       NaN
# 143885    Uluru     22.9     37.7       0.0     5.468232       NaN
# 143886    Uluru     24.0     39.0       0.0     5.468232       NaN
# ...         ...      ...      ...       ...          ...       ...
# 145455    Uluru      2.8     23.4       0.0     5.468232       NaN
# 145456    Uluru      3.6     25.3       0.0     5.468232       NaN
# 145457    Uluru      5.4     26.9       0.0     5.468232       NaN
# 145458    Uluru      7.8     27.0       0.0     5.468232       NaN
# 145459    Uluru     14.9      NaN       0.0     5.468232       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# ...
